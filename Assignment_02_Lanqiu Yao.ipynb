# %% [markdown]
# # Pandas and Matplotlib Homework

# %%
#load the libraries using the normal convention
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
##prevent plotting errors
# %matplotlib inline

# %%
#Load our excel files of interest into pandas
NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheetname=0) 
GAA_ = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheetname='5vs5')
# Out:
# /Users/yaolanqiu/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
NHL_Goalies.head()
# Out:
#   Last Name First Name Team         DOB      Birth City  S/P Cntry  Nat  Ht  \
# 0     Allen       Jake  STL  1990-08-07     Fredericton   NB   CAN  CAN  74
# 1     Alves      Jorge  CAR  1979-01-30          Boston   MA   USA  USA  69
# 2  Andersen   Frederik  TOR  1989-10-02         Herning  NaN   DNK  DNK  76
# 3  Anderson      Craig  OTT  1981-05-21      Park Ridge   IL   USA  USA  74
# 4   Bachman    Richard  VAN  1987-07-25  Salt Lake City   UT   USA  USA  70
#
#     Wt   ...      Cap Hit        Pace  1st  2nd  3rd  Star   GPS  Ginj  \
# 0  203   ...    2350000.0  104.033662  9.0  7.0  6.0  22.0   9.8   NaN
# 1  185   ...          NaN    0.000000  NaN  NaN  NaN   NaN   0.0   NaN
# 2  230   ...    5000000.0  118.931391  9.0  6.0  6.0  21.0  13.1   2.0
# 3  187   ...    4200000.0  114.858819  8.0  2.0  5.0  15.0   9.2   2.0
# 4  183   ...     575000.0  113.421038  1.0  0.0  1.0   2.0   1.1   NaN
#
#      Injuries    CHIP
# 0         NaN
# 1         NaN
# 2  Upper body  121951
# 3  Lower body  102439
# 4         NaN
#
# [5 rows x 111 columns]

# %%
GAA_.head()
# Out:
#   First Name Last Name Team      TOI       GAA       GSAA       SV%   TrueSV%  \
# 0      Allen      Jake  STL  2692.83  2.139014   1.718026  0.924588  0.959630
# 1      Alves     Jorge  CAR     0.13  0.000000   0.000000  0.000000  0.000000
# 2   Andersen  Frederik  TOR  2997.20  2.342186   6.510058  0.927284  0.961078
# 3   Anderson     Craig  OTT  1908.44  1.854918  16.994380  0.940404  0.969255
# 4    Bachman   Richard  VAN   244.84  2.695638  -0.330082  0.920863  0.958015
#
#      ExpSV%  xGSAA  ...     SF     xGF   GF  RebF  RushF      Supp       ZS%  \
# 0  0.923551   1.32  ...   1307  104.22  113    78     97  2.517797  0.476449
# 1  0.000000   0.00  ...      0    0.00    0     0      0  0.000000  1.000000
# 2  0.916774  16.91  ...   1531  140.48  139    74    181  2.782597  0.478216
# 3  0.922778  17.45  ...    986   78.14   74    95    119  2.326508  0.525227
# 4  0.907626   1.84  ...    107    8.77    8     4     18  1.960464  0.476821
#
#    OZS   DZS   NZS
# 0  789   867   919
# 1    1     0     0
# 2  922  1006  1100
# 3  635   574   647
# 4   72    79    80
#
# [5 rows x 42 columns]

# %% [markdown]
# #Appendix:
#  1. DF = Pandas DataFrame
#  2. NHL_Goalies DF = NHL_Goalies
#  3. GAA_ DF = GAA_

# %% [markdown]
# ### Q1A) Create a new DF (*called NHL_Ones*) by:
# #### Filtering the correct DF for Goalies that played 1 game <font color='red'> (GP = Games played)</font>

# %% [markdown]
# Notes: How would you find the 'GP' column in these files?

# %%
#Answer 1A:
np.where(NHL_Goalies.columns == 'GP')[0]
# Out:
# array([14])

# %%
NHL_Ones = NHL_Goalies[NHL_Goalies.GP == 1].reset_index(drop=True)

# %%
NHL_Ones.head()
# Out:
#   Last Name First Name Team         DOB  Birth City S/P Cntry  Nat  Ht   Wt  \
# 0     Alves      Jorge  CAR  1979-01-30      Boston  MA   USA  USA  69  185
# 1  Campbell       Jack  LAK  1992-01-09  Port Huron  MI   USA  USA  74  197
# 2    Comrie       Eric  WPG  1995-07-06    Edmonton  AB   CAN  CAN  73  175
# 3    Copley    Pheonix  STL  1992-01-18  North Pole  AK   USA  USA  76  196
# 4  Driedger      Chris  OTT  1994-05-18    Winnipeg  MB   CAN  CAN  76  205
#
#    ...    Cap Hit        Pace  1st  2nd  3rd  Star  GPS  Ginj  Injuries  CHIP
# 0  ...        NaN    0.000000  NaN  NaN  NaN   NaN  0.0   NaN       NaN
# 1  ...        NaN   96.000000  NaN  NaN  NaN   NaN  0.1   NaN       NaN
# 2  ...   645000.0  124.451939  NaN  NaN  NaN   NaN  0.2   NaN       NaN
# 3  ...   708750.0  104.864253  NaN  NaN  NaN   NaN -0.1   NaN       NaN
# 4  ...   755000.0  123.000000  NaN  NaN  NaN   NaN -0.2   NaN       NaN
#
# [5 rows x 111 columns]

# %% [markdown]
#  ## Q1B)
#  #### A. Find the value of the minimum Salary for the entire dataset
#  #### B. Replace the missing values from the NHL_Ones DF with this
#  #### C. Create a new DF after replacement by **adding** a column called  "Adjusted_Salary"
#  #### D. I would like to only see the old "Salary" column and the "Adjusted Salary" column from the new Dataframe

# %%
print(NHL_Goalies.iloc[1])
# Out:
# Last Name          Alves
# First Name         Jorge
# Team                 CAR
# DOB           1979-01-30
# Birth City        Boston
# S/P                   MA
# Cntry                USA
# Nat                  USA
# Ht                    69
# Wt                   185
# Sh                     L
# Dft Yr               NaN
# Rd                   NaN
# Ovrl                 NaN
# GP                     1
# GS                     0
# GR                     1
# W                      0
# L                      0
# T                      0
# OTL                    0
# SA                     0
# SV                     0
# GA                     0
# SV%                    0
# GAA                    0
# GSAA                   0
# MIN             0.133333
# SO                     0
# G                      0
#                  ...
# xGSAA                  0
# ZS%                    1
# OZS                    1
# DZS                    0
# NZS                    0
# CF                     0
# FF                     0
# SF                     0
# xGF                    0
# GF                     0
# RebF                   0
# RushF                  0
# SOS                    0
# SOG                    0
# SO SV%                 0
# SOW                    0
# SOL                    0
# NMC                  NaN
# Status               NaN
# Salary               NaN
# Cap Hit              NaN
# Pace                   0
# 1st                  NaN
# 2nd                  NaN
# 3rd                  NaN
# Star                 NaN
# GPS                    0
# Ginj                 NaN
# Injuries             NaN
# CHIP
# Name: 1, Length: 111, dtype: object

# %% [markdown]
# #### Notes:
# 1. Note where the minimum Salary value is coming & where you are going to assign it to
# 2. Read up on **replacement** of missing values
# 3. Look up Numpy definition for null
# 4. Look up Pandas **Series** Naming
# 5. Review concat function in Pandas
# 6. Review how to slice columns

# %%
#Answer 1B:
np.min(NHL_Goalies.Salary),np.max(NHL_Goalies.Salary)
# Out:
# (575000.0, 9500000.0)

# %%
min_salary = np.min(NHL_Goalies.Salary)

# %%
NHL_Goalies[NHL_Goalies.Salary == min_salary]['Birth City']
# Out:
# 4     Salt Lake City
# 14          Edmonton
# 15         Holliston
# 17             Perth
# 20           Airdrie
# 42            Surrey
# 60             Pisek
# 66       Thunder Bay
# Name: Birth City, dtype: object

# %%
NHL_Goalies['Adjusted Salary'] = NHL_Goalies.Salary.fillna(min_salary)

# %%
salary = NHL_Goalies[list(['Salary','Adjusted Salary'])]

# %%
salary.head()
# Out:
#       Salary  Adjusted Salary
# 0  2500000.0        2500000.0
# 1        NaN         575000.0
# 2  5000000.0        5000000.0
# 3  4750000.0        4750000.0
# 4   575000.0         575000.0

# %% [markdown]
# ### Q2) A. Subset the NHL goalies data to include Goalies that played in more than 25 games AND have a GAA lower than 3.00 and store the New DF as 'workhorse'

# %% [markdown]
# Notes:
# 1. Review notes creating "boolean" masks
# 2. Internet search for Multiple Boolean indexing on multiple columns in a Pandas DataFrame

# %%
#Answer 2:
NHL_subset = NHL_Goalies[(NHL_Goalies.GP > 25) & (NHL_Goalies.GAA < 3)].reset_index(drop=True)
NHL_subset.head()
# Out:
#   Last Name First Name      Team         DOB   Birth City  S/P Cntry  Nat  Ht  \
# 0     Allen       Jake       STL  1990-08-07  Fredericton   NB   CAN  CAN  74
# 1  Andersen   Frederik       TOR  1989-10-02      Herning  NaN   DNK  DNK  76
# 2  Anderson      Craig       OTT  1981-05-21   Park Ridge   IL   USA  USA  74
# 3   Bernier   Jonathan       ANA  1988-08-07        Laval   QC   CAN  CAN  72
# 4    Bishop        Ben  TBL, LAK  1986-11-21       Denver   CO   USA  USA  79
#
#     Wt       ...               Pace  1st  2nd  3rd  Star   GPS  Ginj  \
# 0  203       ...         104.033662  9.0  7.0  6.0  22.0   9.8   NaN
# 1  230       ...         118.931391  9.0  6.0  6.0  21.0  13.1   2.0
# 2  187       ...         114.858819  8.0  2.0  5.0  15.0   9.2   2.0
# 3  184       ...         113.938340  5.0  0.0  2.0   7.0   6.0   3.0
# 4  216       ...         108.466747  0.0  1.0  5.0   6.0   5.7   9.0
#
#      Injuries    CHIP  Adjusted Salary
# 0         NaN                2500000.0
# 1  Upper body  121951        5000000.0
# 2  Lower body  102439        4750000.0
# 3  Upper body  151829        4150000.0
# 4  Lower body  653049        5950000.0
#
# [5 rows x 112 columns]

# %%
NHL_subset.shape
# Out:
# (44, 112)

# %% [markdown]
# ### Q3. Create 2 python functions that:
# <br> </br>
# #### A. Creates/*Returns* a new DataFrame that displays the number of missing values in every column.
# #### This new DataFrame has one new column named "Missing" with the sum of the missing values from the columns

# %% [markdown]
# ### Notes
# ***Function takes one argument: An input DataFrame***
# <br> </br>
# <br> </br>
# ** One Proposed method:**
# 1. Create a pandas series object from the sum of the nulls in every column
# 2. Convert the series object to a DataFrame and pass the list of column names from the input DataFrame as the index. (read Pandas Help online)
# 3. During the conversion of the series object to a DataFrame pass a columns argument to create a name for the new Output DataFrame's Column.

# %% [markdown]
# ### Expected Output:
# <img src='Missing_cols_expectedoutput.png'>

# %%
# Answer 3A: CODE HERE; Please comment each part
def Missing_Cols(data):
    col = data.columns
    for i in range(data.shape[1]):
        print(col[i],np.sum(data[col[i]].isna()))

# %%
NHL_Goalies.loc[:,'Team']
# Out:
# 0          STL
# 1          CAR
# 2          TOR
# 3          OTT
# 4          VAN
# 5          ANA
# 6          FLA
# 7          NYI
# 8          TOR
# 9     TBL, LAK
# 10         CBJ
# 11         EDM
# 12    LAK, TBL
# 13         LAK
# 14         WPG
# 15    PIT, OTT
# 16         STL
# 17         DET
# 18         CHI
# 19         CHI
# 20         SJS
# 21         ARI
# 22         OTT
# 23         MIN
# 24         CGY
# 25         TOR
# 26         PIT
# 27         CBJ
# 28         ANA
# 29         CGY
#         ...
# 65         DET
# 66         PIT
# 67         CAR
# 68         PHI
# 69         DAL
# 70         BUF
# 71         WPG
# 72         ARI
# 73         COL
# 74         MTL
# 75         LAK
# 76         NYR
# 77         BOS
# 78         FLA
# 79         NSH
# 80         CGY
# 81         NSH
# 82         NJD
# 83         COL
# 84         ARI
# 85         MIN
# 86         PHI
# 87         BOS
# 88         EDM
# 89         ANA
# 90         BUF
# 91         COL
# 92         TBL
# 93         CAR
# 94         LAK
# Name: Team, Length: 95, dtype: object

# %%
Missing_Cols(NHL_Goalies)
# Out:
# Last Name 0
# First Name 0
# Team 0
# DOB 0
# Birth City 0
# S/P 34
# Cntry 0
# Nat 0
# Ht 0
# Wt 0
# Sh 0
# Dft Yr 17
# Rd 17
# Ovrl 17
# GP 0
# GS 0
# GR 0
# W 0
# L 0
# T 0
# OTL 0
# SA 0
# SV 0
# GA 0
# SV% 0
# GAA 0
# GSAA 0
# MIN 0
# SO 0
# G 0
# A 0
# PTS 0
# PIM 0
# PenT 0
# PenD 0
# PenDf 0
# Supp 0
# QoC 1
# StMin 0
# StSV 0
# StGA 0
# StSV% 0
# StGAA 0
# QS 0
# QS% 0
# RBS 0
# Pull 8
# ReMin 0
# ReSV 0
# ReGA 0
# ReSV% 0
# ReGAA 0
# Dist 1
# Reb 0
# Rush 0
# DS 0
# HighS 0
# HighG 0
# HighSV% 0
# MedS 0
# MedG 0
# LowS 0
# LowG 0
# AdjSV% 0
# EVSA 0
# EVGA 0
# EV SV% 0
# PP SA 0
# PP GA 0
# PP SV% 0
# SH SA 0
# SH GA 0
# SH SV% 0
# AdjSV%.1 0
# CA 0
# FA 0
# SA.1 0
# xGA 0
# GA.1 0
# TrueSV% 1
# ExpSV% 1
# xGSAA 0
# ZS% 0
# OZS 0
# DZS 0
# NZS 0
# CF 0
# FF 0
# SF 0
# xGF 0
# GF 0
# RebF 0
# RushF 0
# SOS 0
# SOG 0
# SO SV% 0
# SOW 0
# SOL 0
# NMC 77
# Status 6
# Salary 6
# Cap Hit 6
# Pace 0
# 1st 23
# 2nd 23
# 3rd 23
# Star 23
# GPS 0
# Ginj 58
# Injuries 58
# CHIP 0
# Adjusted Salary 0

# %% [markdown]
# #### B. Creates a new *column* called 'missing_values' in the input DF that sums the missing values in each row.

# %% [markdown]
# ### Notes:
# ***Function takes one argument: An input DataFrame***
# <br> </br>
# <br> </br>
# Check out how to use axis argument and how to create new columns in an existing dataframe

# %% [markdown]
# ### Expected Output:
# <img src= 'missingrows_expectedoutput.png'>

# %%
#Answer 3B here; Please comment each part
def missing_values(data):
    missing = []
    for i in range(data.shape[0]):
        missing.append(np.sum(data.loc[i].isna()))
    res = pd.DataFrame({'Injuries':data.Injuries, 'CHIP': data.CHIP, 'missing':missing})
    return(res)

# %%
missing_values(NHL_Goalies)
# Out:
#                   Injuries         CHIP  missing
# 0                      NaN                     3
# 1                      NaN                    18
# 2               Upper body       121951        2
# 3               Lower body       102439        1
# 4                      NaN                     3
# 5               Upper body       151829        1
# 6                      NaN                     8
# 7                      NaN                     3
# 8                      NaN                     7
# 9               Lower body       653049        0
# 10                 Illness       181098        4
# 11                     NaN                     3
# 12                     NaN                     4
# 13                     NaN                    11
# 14                     NaN                     7
# 15                     NaN                     6
# 16                     NaN                    10
# 17                     NaN                     6
# 18   Appendectomy, Illness       804878        0
# 19              Upper body      35823.2        1
# 20                     NaN                     6
# 21  Lower body, Lower body      76829.3        1
# 22                     NaN                     8
# 23                     NaN                     2
# 24                 Illness      30487.8        1
# 25                     NaN                     8
# 26                     NaN                     2
# 27                     NaN                     8
# 28               Lowe body       364634        1
# 29                     NaN                     3
# ..                     ...          ...      ...
# 65                     NaN                     4
# 66        Hand, Lower body      61300.8        1
# 67                     NaN                    11
# 68       Knee, Undisclosed       535061        2
# 69                     NaN                     6
# 70             Undisclosed      36585.4        2
# 71        Lower body, Knee  1.14146e+06        2
# 72                     NaN                     7
# 73                     NaN                     3
# 74                     Flu       237805        0
# 75              Lower body  4.17317e+06        1
# 76              Lower body      60975.6        5
# 77              Lower body       341463        1
# 78             Undisclosed       124390        1
# 79     Illness, Lower body       170732        1
# 80                     NaN                    15
# 81                     NaN                     4
# 82                     NaN                     2
# 83                     NaN                     3
# 84     Lower body, Illness       898374        0
# 85                     NaN                     3
# 86                     NaN                     3
# 87                     NaN                     7
# 88                     NaN                     5
# 89                     NaN                    11
# 90                     NaN                     8
# 91  Upper body, Groin, Hip  3.59756e+06        2
# 92                     NaN                     4
# 93                     NaN                     2
# 94              Lower body       120732        5
#
# [95 rows x 3 columns]

# %% [markdown]
# ### Q4) Matplotlib Question Plot in one figure and 2 side by side plots:
# <br> </br>
# #### A. Plot the histogram of the all the GAA of the NHL_Goalies DF  AND the goalies that played in more than 25 games with a GAA < 3.00,
# #### B. Label the Titles of the plots differently (*ie EntireSet + Subset*)
# #### C. Change the color of one of the plots from the default

# %% [markdown]
# # Notes
#
# 1. convert your column of interest into a NumPY array (look up online for usage)
# 2. Review: https://matplotlib.org/devdocs/api/_as_gen/matplotlib.pyplot.hist.html

# %%
#Answer 4 here: pleae comment
x = np.random.normal(size = 10)
plt.hist(x, normed=True, bins=30, color="red")
plt.ylabel('Probability')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Mercator: Projection of the Oppressor')
# Out:
# /Users/yaolanqiu/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6510: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Text(0.5, 1.0, 'Mercator: Projection of the Oppressor')

# %% [markdown]
# ### Q5) GroupBy Question
# ##### 1. Subset the NHL_Goalies DataFrame where Injuries is not known <font color='red'>(Injuries=NaN)</font>;
# ##### 2. Use a Merge with the GAA_  DF to produce a NEW DF (*called mergedDF*)
# ###### *** USE A JOIN THAT PRESERVES ORDER AND USES THE INTERSECTION OF KEYS***
# ###### *** USE BOTH THE LEFT AND RIGHT INDEXES AS JOIN KEYS***
# ##### 3. From the mergedDF keep FirstName/LastName/Team/Cntry/ SV% /GA/GAA/ TOI (note one copy for any duplicate column)
# ##### 4. GroupBy country on mergedDF and aggregate The Means, Mins, and Maximum of the kept columns
# #### 5. Create a dataframe of the <font color='red'>TOI </font>groupby object and write it to a comma seperated value file called ('TOI_2017.csv')

# %%
NHL_a = NHL_Goalies[NHL_Goalies.Injuries.isna() == False].reset_index(drop=True)

# %%
mergedDF = GAA_.merge(NHL_a,left_on = ['First Name','Last Name'],right_on = ['Last Name','First Name']).reset_index(drop=True)

# %%
mergedDF = mergedDF[list(['First Name_x','Last Name_x','Team_x','TOI','SV%_x','Cntry','GA_x','GAA_x'])]

# %%
mergedDF.head()
# Out:
#   First Name_x Last Name_x    Team_x      TOI     SV%_x Cntry  GA_x     GAA_x
# 0     Andersen    Frederik       TOR  2997.20  0.927284   DNK   117  2.342186
# 1     Anderson       Craig       OTT  1908.44  0.940404   USA    59  1.854918
# 2      Bernier    Jonathan       ANA  1535.89  0.922659   CAN    57  2.226722
# 3       Bishop         Ben  TBL, LAK  1700.08  0.924505   USA    61  2.152840
# 4    Bobrovsky      Sergei       CBJ  2947.94  0.938705   RUS    89  1.811434

# %%
mergedDF.groupby(['Cntry'])['TOI','SV%_x','GA_x','GAA_x'].agg(['mean','min','max'])
# Out:
#                TOI                       SV%_x                      \
#               mean      min      max      mean       min       max
# Cntry
# CAN    1916.320833   161.66  2944.40  0.919341  0.859155  0.935897
# CZE     724.000000   367.04  1080.96  0.905365  0.902128  0.908602
# DNK    2997.200000  2997.20  2997.20  0.927284  0.927284  0.927284
# FIN    2301.716667  1265.13  2850.93  0.927626  0.920509  0.933121
# KAZ     687.190000   687.19   687.19  0.906752  0.906752  0.906752
# RUS    1990.595000  1033.25  2947.94  0.920230  0.901754  0.938705
# SWE    1457.675000   275.78  2718.53  0.919504  0.899160  0.931507
# USA    1424.390000   453.09  2646.83  0.923663  0.876344  0.940404
#
#              GA_x               GAA_x
#              mean  min  max      mean       min       max
# Cntry
# CAN     73.000000   10  109  2.424324  1.833990  3.711493
# CZE     31.500000   17   46  2.666137  2.553286  2.778989
# DNK    117.000000  117  117  2.342186  2.342186  2.342186
# FIN     79.666667   42  100  2.061056  1.991890  2.104576
# KAZ     29.000000   29   29  2.532051  2.532051  2.532051
# RUS     72.500000   56   89  2.531655  1.811434  3.251875
# SWE     58.333333   12  110  2.393215  2.213390  2.610777
# USA     50.800000   23  104  2.216756  1.854918  3.045752

# %%
mergedDF.groupby(['Cntry'])['TOI'].agg(['mean','min','max']).to_csv('TOI.csv')

# %% [markdown]
# ## Notes:
#
# 1. Review or read up pandas documentation on:
#     - how to create selection criteria
#     - how aggs/joins work: https://pandas.pydata.org/pandas-docs/stable/merging.html
# 2. https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html
# 3. https://stackoverflow.com/questions/14734533/how-to-access-pandas-groupby-dataframe-by-key
# 4. https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.get.html

# %%
#Answer 5 here: please comments

# %% [markdown]
# # Q6) Write a function(s)
# ## that subsets a dataframe by removing rows that are WITHIN the InterQuartile Region of a specified column
# <br> </br>
# ### The function takes as input
# ##### A: Pandas_Dataframe (For example use NHL_GoaliesDF)
# ##### B. Column name
# ### Add a condition that returns an error if the Column Name chosen is not:
# ##### A. Numeric Dtype
# ##### B. Does not exist in the Numeric Columns
# ### The output is a DataFrame that removes rows outside of the specified columns IQR
# <br> </br>
# <font color='red'>**You can use smaller helper functions **<font>
# <br> </br>
# See --> <href>=https://en.wikipedia.org/wiki/Interquartile_range</href>
# #hint: There are several pandas subfunctions that can be useful

# %%
def iqr(data,col_name):
    if data[col_name].dtypes in ['float','int']:
        x = data[col_name]
        q75, q25 = np.percentile(x, [75 ,25])
        res = data[(data[col_name] < q25) | (data[col_name] > q75)]
        return(res)
    else:
        print('not a number')

# %%
mergedDF['TOI'].dtypes in ['float','int']
# Out:
# True

# %%
iqr(mergedDF, 'First Name_x')
# Out:
# not a number

# %%
#Answer Question 6 here
